# %%
import os
import logging
import logging.config

basic = {}
log_filename = "logging.log"
logging.basicConfig(level=logging.DEBUG,
    format='[%(asctime)s] %(levelname)s [%(funcName)s: %(filename)s, %(lineno)d] %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    filemode='a')

def list_dir(dirpath):
    #logging.debug("current dir: {0}".format(dirpath))
    dir_list = os.listdir(dirpath)
    basic["dir"] = {"dir":dir_list}
    print(basic)
    return dir_list
    

def log(dirpath):
    dir_list = list_dir(dirpath)
    print(dir_list)
    
if __name__ == '__main__':
    dirpath = "E:/share/3.0.3/ALEISSUE/ALE-268/Stellar/"  # 指定根目录
    log(dirpath)
# Out:
# current dir: E:/share/3.0.3/ALEISSUE/ALE-268/Stellar/
# ['DC08560309A0_snapshot_20181115145000', 'DC08560309A0_snapshot_20181115145000.tar.gz', 'DC08560309A0_snapshot_20181115150935', 'DC08560309A0_snapshot_20181115150935.tar.gz', 'DC08560309A0_snapshot_20181115151008', 'DC08560309A0_snapshot_20181115151008.tar.gz', 'DC08560309A0_snapshot_20181115152944', 'DC08560309A0_snapshot_20181115152944.tar.gz', 'DC08560309A0_snapshot_20181115153017', 'DC08560309A0_snapshot_20181115153017.tar.gz', 'DC08560309A0_snapshot_20181115154953', 'DC08560309A0_snapshot_20181115154953.tar.gz', 'DC08560309A0_snapshot_20181115155026', 'DC08560309A0_snapshot_20181115155026.tar.gz', 'DC08560309A0_snapshot_20181115161002', 'DC08560309A0_snapshot_20181115161002.tar.gz', 'DC08560309A0_snapshot_20181115161035', 'DC08560309A0_snapshot_20181115161035.tar.gz', 'DC08560309A0_snapshot_20181115163010', 'DC08560309A0_snapshot_20181115163010.tar.gz', 'DC08560309A0_snapshot_20181115163044', 'DC08560309A0_snapshot_20181115163044.tar.gz', 'DC08560309A0_snapshot_20181115165018', 'DC08560309A0_snapshot_20181115165018.tar.gz', 'DC08560309A0_snapshot_20181115165052', 'DC08560309A0_snapshot_20181115165052.tar.gz', 'DC08560309A0_snapshot_20181115171028', 'DC08560309A0_snapshot_20181115171028.tar.gz', 'DC08560309A0_snapshot_20181115171102', 'DC08560309A0_snapshot_20181115171102.tar.gz', 'DC08560309A0_snapshot_20181115173037', 'DC08560309A0_snapshot_20181115173037.tar.gz', 'DC08560309A0_snapshot_20181115173111', 'DC08560309A0_snapshot_20181115173111.tar.gz', 'DC08560309A0_snapshot_20181115175046', 'DC08560309A0_snapshot_20181115175046.tar.gz', 'DC08560309A0_snapshot_20181115175119', 'DC08560309A0_snapshot_20181115175119.tar.gz', 'DC08